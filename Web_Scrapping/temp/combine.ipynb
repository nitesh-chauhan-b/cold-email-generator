# %%
import pandas as pd

# %% [markdown]
# ### Combining Scrapped Data

# %%
# ms_jobs = pd.read_csv("MS_Jobs.csv")
apple_jobs = pd.read_csv("Apple_Jobs.csv")
ibm_jobs = pd.read_csv("IBM_Jobs.csv")
capegemini_jobs = pd.read_csv("Capgemini_Jobs.csv")
oracle_jobs = pd.read_csv("Oracle_Jobs.csv")
sap_jobs = pd.read_csv("SAP_Jobs.csv")

# %%
# ms_jobs.drop(columns=["Unnamed: 0"],inplace=True)
# ms_jobs.to_csv("MS_Jobs.csv",index=True)

# %%
#Renaming column
ms_jobs.rename(columns={"Links":"Link"},inplace=True)
ms_jobs.to_csv("MS_Jobs.csv",index=False)

# %%
combined_df = pd.concat([ibm_jobs,apple_jobs,oracle_jobs,capegemini_jobs,sap_jobs])

# %%
combined_df
# Out:
#    Unnamed: 0                 Field  \
# 0           0  Software Engineering
# 1           1  Software Engineering
# 2           2  Software Engineering
# 3           3  Software Engineering
# 4           4  Software Engineering
# ..        ...                   ...
# 59         59  Software Engineering
# 60         60  Software Engineering
# 61         61  Software Engineering
# 62         62  Software Engineering
# 63         63  Software Engineering
#
#                                                 Title Company Posted At  \
# 0                         Software Developer - Python     IBM       NaN
# 1                         Software Developer - Python     IBM       NaN
# 2                         Software Developer - Python     IBM       NaN
# 3                         Software Developer - Python     IBM       NaN
# 4                         Software Developer - Python     IBM       NaN
# ..                                                ...     ...       ...
# ...

# %%
combined_df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
combined_df
# Out:
#                    Field                                              Title  \
# 0   Software Engineering                        Software Developer - Python
# 1   Software Engineering                        Software Developer - Python
# 2   Software Engineering                        Software Developer - Python
# 3   Software Engineering                        Software Developer - Python
# 4   Software Engineering                        Software Developer - Python
# ..                   ...                                                ...
# 59  Software Engineering                            HANA Expert - 15+ years
# 60  Software Engineering    Senior Database Specialist - IBM DB2 & SAP HANA
# 61  Software Engineering             Development Expert-Analytics Architect
# 62  Software Engineering           IT Business Services PrincipalConsultant
# 63  Software Engineering  Bangalore - SAP Basis Technology Consultant (M...
#
#    Company Posted At                   Location  \
# ...

# %%
# combined_df.drop(columns=["Unnamed: 0"],inplace=True)
combined_df.to_csv("All_Jobs.csv",index=False)
